# %% [markdown]
# ### Extract SQL Table Information Schema in JSON Format

# %%
import sqlite3
import json

def get_table_info(database_path, table_name):
    conn = sqlite3.connect(database_path)
    cursor = conn.cursor()

    # Query to get table information
    query = f"""
    SELECT
        name as column_name,
        type as data_type,
        [notnull] as is_nullable,
        dflt_value as column_default,
        pk as is_primary_key
    FROM
        pragma_table_info('{table_name}')
    ORDER BY
        cid;
    """

    cursor.execute(query)
    columns = [description[0] for description in cursor.description]
    rows = cursor.fetchall()

    # Convert the results to a list of dictionaries
    table_info = [dict(zip(columns, row)) for row in rows]

    # Close the connection
    conn.close()

    return table_info

def main():
    database_path = 'QTX_BankData.db'  # SQLite database path
    table_name = 'GL_Fact'  # Table name to inspect

    table_info = get_table_info(database_path, table_name)

    # Print the results as formatted JSON
    print(json.dumps(table_info, indent=2))

    # Optionally, you can also save the results to a file
    with open(f'{table_name}_info.json', 'w') as f:
        json.dump(table_info, f, indent=2)

if __name__ == "__main__":
    main()
# Out:
# [
#   {
#     "column_name": "Period",
#     "data_type": "TEXT",
#     "is_nullable": 0,
#     "column_default": null,
#     "is_primary_key": 0
#   },
#   {
#     "column_name": "InterCo",
#     "data_type": "TEXT",
#     "is_nullable": 0,
#     "column_default": null,
#     "is_primary_key": 0
#   },
#   {
#     "column_name": "GL Account",
#     "data_type": "INTEGER",
#     "is_nullable": 0,
#     "column_default": null,
#     "is_primary_key": 0
#   },
#   {
#     "column_name": "Project",
#     "data_type": "TEXT",
#     "is_nullable": 0,
#     "column_default": null,
#     "is_primary_key": 0
#   },
#   {
#     "column_name": "Scenario",
#     "data_type": "TEXT",
#     "is_nullable": 0,
#     "column_default": null,
#     "is_primary_key": 0
#   },
#   {
#     "column_name": "Entity",
#     "data_type": "TEXT",
#     "is_nullable": 0,
#     "column_default": null,
#     "is_primary_key": 0
#   },
#   {
#     "column_name": "Measure",
#     "data_type": "TEXT",
#     "is_nullable": 0,
#     "column_default": null,
#     "is_primary_key": 0
#   },
#   {
#     "column_name": "Product",
#     "data_type": "TEXT",
#     "is_nullable": 0,
#     "column_default": null,
#     "is_primary_key": 0
#   },
#   {
#     "column_name": "Value",
#     "data_type": "REAL",
#     "is_nullable": 0,
#     "column_default": null,
#     "is_primary_key": 0
#   },
#   {
#     "column_name": "Financial_Value",
#     "data_type": "REAL",
#     "is_nullable": 0,
#     "column_default": null,
#     "is_primary_key": 0
#   },
#   {
#     "column_name": "Period_EndDate",
#     "data_type": "TEXT",
#     "is_nullable": 0,
#     "column_default": null,
#     "is_primary_key": 0
#   },
#   {
#     "column_name": "Major GL Account",
#     "data_type": "TEXT",
#     "is_nullable": 0,
#     "column_default": null,
#     "is_primary_key": 0
#   }
# ]

# %% [markdown]
# ### Extract Summarized Loan Balances in JSON

# %%
import sqlite3
import json

def sum_loans_by_date(database_path):
    conn = sqlite3.connect(database_path)
    cursor = conn.cursor()

    query = """
    SELECT 
        Period_EndDate,
        SUM(Value) as TotalValue,
        Scenario
    FROM 
        GL_Fact
    WHERE 
        [Major GL Account] = 'Assets'
    GROUP BY 
        Period_EndDate, Scenario
    ORDER BY 
        Period_EndDate, Scenario
    """

    try:
        cursor.execute(query)
        results = cursor.fetchall()

        # Convert results to a list of dictionaries
        json_data = [
            {
                "Period_EndDate": row[0],
                "Scenario": row[1],
                "TotalValue": row[2]
            }
            for row in results
        ]

        # Convert to JSON format
        json_output = json.dumps(json_data, indent=2)

        print("Query results:")
        print(json_output)

        # Optionally, save to a file
        with open('loans_sum_by_date.json', 'w') as f:
            f.write(json_output)
        print("\nResults have been saved to 'loans_sum_by_date.json'")

    except sqlite3.Error as e:
        print(f"An error occurred: {e}")

    finally:
        conn.close()

def main():
    database_path = 'QTX_BankData.db'  # SQLite database path
    sum_loans_by_date(database_path)

if __name__ == "__main__":
    main()
# Out:
# Query results:
# [
#   {
#     "Period_EndDate": "01/31/2022",
#     "Scenario": 9680.0,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "01/31/2022",
#     "Scenario": 2056.003599291299,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "01/31/2022",
#     "Scenario": 10071.352510914894,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "01/31/2023",
#     "Scenario": 19132.0,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "01/31/2023",
#     "Scenario": 3341.0,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "01/31/2023",
#     "Scenario": 8421.0,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "01/31/2024",
#     "Scenario": 34812.24045709291,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "01/31/2024",
#     "Scenario": 8857.0,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "01/31/2024",
#     "Scenario": 3895.055312445194,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "02/28/2022",
#     "Scenario": 33012.38039366339,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "02/28/2022",
#     "Scenario": 20820.61885545438,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "02/28/2023",
#     "Scenario": 22299.309479715666,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "02/28/2023",
#     "Scenario": 11822.500711243956,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "02/29/2024",
#     "Scenario": 32728.573304747617,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "03/31/2022",
#     "Scenario": 37776.469980390444,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "03/31/2022",
#     "Scenario": 7204.287881432934,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "03/31/2023",
#     "Scenario": 26567.447407446303,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "03/31/2023",
#     "Scenario": 8635.0,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "03/31/2023",
#     "Scenario": 18749.03086672307,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "03/31/2024",
#     "Scenario": 36902.293626838655,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "03/31/2024",
#     "Scenario": 9545.0,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "04/30/2022",
#     "Scenario": 7737.0,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "04/30/2023",
#     "Scenario": 32520.98769989368,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "04/30/2023",
#     "Scenario": 6803.0,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "04/30/2024",
#     "Scenario": 26139.6549501502,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "04/30/2024",
#     "Scenario": 7043.656094494344,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "05/31/2022",
#     "Scenario": 43626.49427697744,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "05/31/2022",
#     "Scenario": 17065.776337377327,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "05/31/2022",
#     "Scenario": 18046.077863334005,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "05/31/2023",
#     "Scenario": 63123.858719768716,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "05/31/2024",
#     "Scenario": 27401.87369213373,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "05/31/2024",
#     "Scenario": 7639.0,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "05/31/2024",
#     "Scenario": 8347.036501062754,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "06/30/2022",
#     "Scenario": 16513.094936195143,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "06/30/2022",
#     "Scenario": 26026.189066271254,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "06/30/2023",
#     "Scenario": 59172.522073950226,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "06/30/2024",
#     "Scenario": 22299.266847788585,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "06/30/2024",
#     "Scenario": 13170.20496196743,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "07/31/2022",
#     "Scenario": 19182.113455643994,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "07/31/2022",
#     "Scenario": 3586.585363363436,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "07/31/2023",
#     "Scenario": 14847.0,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "07/31/2023",
#     "Scenario": 4150.0,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "08/31/2022",
#     "Scenario": 37450.4970098152,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "08/31/2022",
#     "Scenario": 13007.1447465041,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "08/31/2023",
#     "Scenario": 17835.99698239369,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "08/31/2023",
#     "Scenario": 6879.0,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "09/30/2022",
#     "Scenario": 22274.190171217033,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "09/30/2023",
#     "Scenario": 52313.55750074116,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "09/30/2023",
#     "Scenario": 3983.0,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "09/30/2023",
#     "Scenario": 19624.778960958633,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "10/31/2022",
#     "Scenario": 8881.697824690977,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "10/31/2022",
#     "Scenario": 1498.0,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "10/31/2022",
#     "Scenario": 7144.990173711949,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "10/31/2023",
#     "Scenario": 32448.257682376337,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "10/31/2023",
#     "Scenario": 12884.896828600622,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "11/30/2022",
#     "Scenario": 41316.43698352041,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "11/30/2022",
#     "Scenario": 10340.486078903352,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "11/30/2022",
#     "Scenario": 3427.926947389458,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "11/30/2023",
#     "Scenario": 35682.341129667184,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "11/30/2023",
#     "Scenario": 4925.0,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "12/31/2022",
#     "Scenario": 27728.65856026586,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "12/31/2022",
#     "Scenario": 9149.981547747135,
#     "TotalValue": "Budget"
#   },
#   {
#     "Period_EndDate": "12/31/2022",
#     "Scenario": 18746.235541897746,
#     "TotalValue": "Forecast"
#   },
#   {
#     "Period_EndDate": "12/31/2023",
#     "Scenario": 26145.609846242085,
#     "TotalValue": "Actual"
#   },
#   {
#     "Period_EndDate": "12/31/2023",
#     "Scenario": 17979.24053634501,
#     "TotalValue": "Forecast"
#   }
# ]
#
# Results have been saved to 'loans_sum_by_date.json'
